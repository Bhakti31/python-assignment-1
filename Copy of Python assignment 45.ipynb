# %% [markdown]
# Q.1 write a python program to calculate length of string

# %%
str= input("Enter a string= ")

ans= len(str)

print("The lenght of the string", ans)
# Out:
# Enter a string= Happy new year
# The lenght of the string 14

# %% [markdown]
# Q.2 python program to calculate the square root

# %%
import math

Num= int(input("Enter number= "))

ans= math.sqrt(Num)

print("The square root is", ans)
# Out:
# Enter number= 16
# The square root is 4.0

# %% [markdown]
# Q.3 write a python program to convert temperature in Celsius to temperature in Fahrenheit

# %%
temp= int(input("Enter temperature in Celsius= "))

ans= temp*9/5+32

print("The temperaturein Farehiet is", ans)
# Out:
# Enter temperature in Celsius= 32
# The temperaturein Farehiet is 89.6

# %% [markdown]
# Q.4 write a data type needed for given data(10,4.5,2+6j)

# %%
num= 10
ans= type(num)

print("The data type of", num, "is", ans)
# Out:
# The data type of 10 is <class 'int'>

# %%
num= 6.9
ans= type(num)

print("The data type of", num, "is", ans)
# Out:
# The data type of 6.9 is <class 'float'>

# %%
num= 7j+1
ans= type(num)
print("The data type of", num, "is", ans)
# Out:
# The data type of (1+7j) is <class 'complex'>
